# %% [markdown]
# #### Load Env Variables

# %%
from dotenv import load_dotenv
load_dotenv()
# Out:
# True

# %% [markdown]
# #### Connect with Google Gemini model

# %%
from langchain_google_genai import ChatGoogleGenerativeAI
llm = ChatGoogleGenerativeAI(model="gemini-3-flash-preview")

# %%
res = llm.invoke("What is GenAI? Explain me in short?")
print(res.content[0]["text"])
# Out:
# **Generative AI (GenAI)** is a type of artificial intelligence that can **create new content** rather than just analyzing existing data.
#
# While traditional AI is designed to recognize patterns or make predictions (like a Netflix recommendation), GenAI uses what it has learned to generate something original that looks or sounds like it was made by a human.
#
# **Key points:**
# *   **What it creates:** Text, images, music, computer code, and video.
# *   **How it works:** It is trained on massive amounts of data to learn the underlying patterns and structures, then uses those patterns to predict what comes next.
# *   **Popular examples:** **ChatGPT** (text), **DALL-E** or **Midjourney** (images), and **GitHub Copilot** (code).
#
# In short: **Traditional AI *sorts* data; Generative AI *creates* data.**

# %% [markdown]
# #### Connect with OpenAI model

# %%
from langchain_openai import ChatOpenAI
llm = ChatOpenAI(model="gpt-5-nano")

# %%
res = llm.invoke("How to find largest number from a list in python?")
print(res.content)
# Out:
# The simplest way is to use Python’s built-in max function.
#
# - Basic use (numbers in a list):
#   - nums = [1, 4, 2, 9, 5]
#   - largest = max(nums)
#   - print(largest)  # 9
#
# - Handle empty list (Python 3.4+):
#   - largest = max(nums, default=None)  # returns None if nums is empty
#
# - If you want to pick the largest item by some key (e.g., a list of dicts or objects):
#   - items = [{"name": "a", "score": 10}, {"name": "b", "score": 15}]
#   - best = max(items, key=lambda x: x["score"])
#   - print(best)  # {'name': 'b', 'score': 15}
#
# - Alternative (less efficient) approach: sort and take the last element
#   - largest = sorted(nums)[-1]
#
# - If you’re working with NumPy arrays:
#   - import numpy as np
#   - arr = np.array(nums)
#   - largest = arr.max()
#
# Notes:
# - max() runs in O(n) time.
# - It will raise ValueError if the list is empty unless you provide a default via max(nums, default=...). If you expect empty lists, you can handle that with a conditional or use the default form.

# %% [markdown]
# #### Static Prompts

# %%
from langchain_openai import ChatOpenAI
llm = ChatOpenAI(model="gpt-5-nano")

# %%
prompts = [("system", "You are a python developer."),
           ("user", "How to sort the array.")]
res = llm.invoke(prompts)
print(res.content)
# Out:
# Here are the common ways to sort in Python. Let me know what type of “array” you’re using if you want something more specific.
#
# 1) Sorting a Python list (in place)
# - lst.sort()
# - lst.sort(reverse=True)  # descending
#
# 2) Getting a sorted copy (doesn’t modify the original)
# - sorted_list = sorted(lst)
# - sorted(lst, reverse=True)
#
# 3) Sorting with a key (sort by something derived from each element)
# - sort by length: sorted(words, key=len)
# - case-insensitive: sorted(words, key=str.lower)
#
# 4) Sorting a list of dictionaries or objects by a field
# - items_sorted = sorted(items, key=lambda x: x['name'])
# - for objects: sorted(items, key=lambda o: o.name)
#
# 5) Sorting a 2D array / list of rows by a specific column
# - data_sorted = sorted(data, key=lambda row: row[1])  # sort by second column
#
# 6) NumPy arrays (if you’re using numpy)
# - import numpy as np
# - a = np.array([3, 1, 2])
# - b = np.sort(a)      # returns a new sorted array
# - a.sort()              # sorts in place
# - np.sort(a, axis=0)    # along an axis (for multi-dim arrays)
#
# Notes:
# - Python’s sort is stable (preserves relative order of equal elements).
# - For in-place vs new copy, choose sort() vs sorted() accordingly.
#
# If you share an example of your array and the sort criterion (ascending/descending, by a specific field, etc.), I can give you a precise snippet.
