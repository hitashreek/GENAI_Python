# %%
from dotenv import load_dotenv
load_dotenv()
# Out:
# True

# %%
from langchain_groq import ChatGroq
from langchain_openai import ChatOpenAI

# %%
llm = ChatGroq(model="openai/gpt-oss-20b")
# openAILLM = ChatOpenAI(model="gpt-5-nano") # It takes too much time compare to GROQ

# %%
res = llm.invoke("Can you explain GEN-AI?")
# res = openAILLM.invoke("Can you explain GEN-AI?") # eg. 16sec with OpenAI and 2sec with GROQ
print(res.content)
# Out:
# ## What is GEN‑AI?
# **GEN‑AI** is a shorthand for **Generative Artificial Intelligence** – the branch of AI that creates *new* data instead of merely classifying or predicting it. Think of it as the “artist” or “inventor” of the AI world, as opposed to the “detective” that only looks for patterns in existing data.
#
# ---
#
# ## 1. The Core Idea
#
# | Traditional (Discriminative) AI | Generative AI |
# |---------------------------------|---------------|
# | Learns to map *input → output* (e.g., image → label) | Learns to *sample from the underlying data distribution* (e.g., generate a new image, write a story, compose music) |
# | Example: a spam filter | Example: GPT‑4 writing an essay |
# | Focus: accuracy on a fixed task | Focus: creativity, variety, and realism |
#
# ---
#
# ## 2. How It Works (High‑Level)
#
# 1. **Data Collection**
#    - Gather a large, diverse dataset (text, images, audio, etc.).
#    - The dataset defines the “style” and “knowledge” the model will learn.
#
# ...
