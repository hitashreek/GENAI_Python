# %%
from dotenv import load_dotenv
load_dotenv()
# Out:
# True

# %%
from langchain_community.utilities import GoogleSerperAPIWrapper
from langchain_groq import ChatGroq
from langchain.agents import create_agent
from langgraph.checkpoint.memory import InMemorySaver

# %%
model = ChatGroq(model="openai/gpt-oss-20b")
search = GoogleSerperAPIWrapper()

# %%
agent = create_agent(
  model=model,
  tools=[search.run],
  system_prompt="You are a agent and can search any question on google.",
  checkpointer=InMemorySaver()
)

# %%
question = "Special food?"

# %%
response = agent.invoke({"messages":[{"role":"user", "content":question}]},
                        {"configurable":{"thread_id":"1"}},
    )

# %%
print(response["messages"][-1].content)
# Out:
# Could you clarify what you mean by “special food”?
# - Are you looking for a particular dish, a type of cuisine, a recipe, a dietary specialty, or something else?
# Let me know a bit more detail so I can provide the best information for you.
