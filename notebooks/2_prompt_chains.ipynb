# %%
from langchain_openai import ChatOpenAI

# %%
llm = ChatOpenAI(model="gpt-5-nano")

# %%
prompts = [
  {"role":"system", "content":"You are a JavaScript Developer"},
  {"role":"user", "content":"Difference between map and filter?"}
]

res = llm.invoke(prompts)
print(res.content)
# Out:
# Short answer:
# - map: transforms every element and returns a new array of the same length.
# - filter: tests each element and returns a new array with only the elements that pass the test (length can be smaller).
#
# Details:
# - map
#   - Purpose: change each element.
#   - Callback: (value, index, array) => newValue
#   - Result: a new array with the results; same length as input (holes are preserved in sparse arrays).
#   - Example:
#     const nums = [1, 2, 3, 4];
#     const doubled = nums.map(n => n * 2); // [2, 4, 6, 8]
#
# - filter
#   - Purpose: select a subset of elements.
#   - Callback: (value, index, array) => boolean
#   - Result: a new array with only the elements for which the callback returned true; length can be smaller.
#   - Example:
#     const nums = [1, 2, 3, 4];
#     const evens = nums.filter(n => n % 2 === 0); // [2, 4]
#
# Common notes:
# - Neither mutates the original array (unless you mutate elements inside the callback).
# - They can be chained (e.g., arr.filter(...).map(...)).
# - If you need to do both in one pass, consider reduce for more complex pipelines.
# - For sparse arrays, both skip holes; map preserves holes, filter skips them as well.
#
# Quick examples with objects:
# - const people = [{name:'Alice', age:25}, {name:'Bob', age:15}];
# - const names = people.map(p => p.name); // ['Alice', 'Bob']
# - const adults = people.filter(p => p.age >= 18); // [{name:'Alice', age:25}]

# %% [markdown]
# #### Prompt Templates - Dynamic Prompts

# %%
from langchain_openai import ChatOpenAI
from langchain_core.prompts import ChatPromptTemplate
from langchain_core.output_parsers import StrOutputParser

# %%
llm = ChatOpenAI(model="gpt-5-nano")
out = StrOutputParser()

# %%
#### My Self Chain Node

def transform_case(result:str):
    return result.upper()

# %%
prompts = ChatPromptTemplate.from_messages([
  {"role":"system", "content":"You are a translator and translate input in {language}"},
  {"role":"user", "content":"{query}"}
])

# %%
# final_prompts = prompts.format_messages(language = "Marathi", query = "I like learning Python and JS")
# final_prompts
# res = llm.invoke(final_prompts)
# print(res.content)

# %%
# res = llm.invoke(prompts.invoke({"language":"Gujrathi", "query":"How are you?"}))
# res.content

# %%
chains = prompts | llm | out | transform_case

# %%
res = chains.invoke({"language":"Hinglish", "query":"I like learning LangChain"})
print(res)
# Out:
# MUJHE LANGCHAIN SEEKHNA PASAND HAI.
