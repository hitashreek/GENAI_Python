# %%
from langchain_ollama import ChatOllama

# %%
llm = ChatOllama(model="gemma3")

# %%
res = llm.invoke("Hello, I am Hita")
res.content
# Out:
# 'Hello Hita! It’s nice to meet you. 😊 \n\nHow are you doing today? Is there anything you’d like to chat about, or were you just saying hello?'

# %%
llm = ChatOllama(model="gemma3")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 llm = ChatOllama(model="gemma3")
#
# NameError: name 'ChatOllama' is not defined

# %%
llm.invoke("Hello, I am Hita")
# Out:
# ---------------------------------------------------------------------------
# ResponseError                             Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 llm.invoke("Hello, I am Hita")
#
# File d:\React\Prateek\GENAI-Series\env\Lib\site-packages\langchain_core\language_models\chat_models.py:454, in BaseChatModel.invoke(self, input, config, stop, **kwargs)
#     440 @override
#     441 def invoke(
#     442     self,
#    (...)    447     **kwargs: Any,
#     448 ) -> AIMessage:
#     449     config = ensure_config(config)
#     450     return cast(
#     451         "AIMessage",
#     452         cast(
#     453             "ChatGeneration",
# --> 454             self.generate_prompt(
#     455                 [self._convert_input(input)],
#     456                 stop=stop,
#     457                 callbacks=config.get("callbacks"),
#     458                 tags=config.get("tags"),
#     459                 metadata=config.get("metadata"),
# ...
