# %%
from dotenv import load_dotenv
load_dotenv()
# Out:
# True

# %%
from langchain_openai import ChatOpenAI
llm = ChatOpenAI(model="gpt-5-nano")

# %%
prompts = [
  {"role":"user", "content":"Hello, I am Hita."},
  {"role":"ai", "content":"Hello, Hita! How can I assist you."},
  {"role":"user", "content":"What is my name?"}
]

res = llm.invoke(prompts)

# %%
res.content
# Out:
# 'Your name is Hita. If you’d like me to remember it for this chat or prefer another name, tell me and I’ll use it. How can I help today, Hita?'

# %% [markdown]
# #### Manage History

# %%
history = []
while True:
# for _ in range(5):
    query = input("User: ")
    if query.lower() in ["exit", "quit", "bye"]:
        print("Good Bye")
        break
    
    history.append({"role":"user", "content":query})
    print("User: ", query)

    res = llm.invoke(history)
    history.append({"role":"ai", "content":res.content})
    print("AI: ", res.content, "\n")
# Out:
# User:  President of India?
# AI:  Droupadi Murmu. She has been the President of India since 25 July 2022 (the 15th president). The term is five years, so her term would end around 2027, unless a change occurs. If you want a quick bio or details about the president’s role, I can share that.
#
# User:  DOB?
# AI:  20 June 1958.
#
# User:  Earlier proffesions?
# AI:  - Teacher in a government school in Odisha (early career).
# - Local government/public service roles in Odisha, including serving as chairperson of the Rairangpur Nagar Panchayat (a local body).
# - Politician with the BJP; later appointed Governor of Jharkhand (2015–2021) before becoming President of India (2022–present).
#
# User:  Latest update?
# AI:  Latest update: Droupadi Murmu is the President of India. She was sworn in on 25 July 2022, and her term is for five years (to 2027), unless a change occurs earlier. No official reports of any change in status as of my last update.
#
# If you want the most current status, check reliable sources like:
# - Official President of India site (presidentofindia.nic.in)
# - Rashtrapati Bhavan press releases
# - Reputable news outlets
#
# Would you like a quick summary of her recent activities or initiatives as President?
